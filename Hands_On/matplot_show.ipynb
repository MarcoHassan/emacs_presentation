# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
# %config InlineBackend.figure_format = 'png'
import numpy as np
import pandas as pd

# %%
X = 2 * np.random.rand(100,1)
y = 4 +3 * X+np.random.randn(100,1)

mydat = pd.DataFrame ({'x':X.flatten(), 'y': y.flatten()})

mydat.columns = ["nomean", "posmean"]

# %%
plt.plot(mydat.nomean, c = "lightblue", ls = '--', marker = "o",
         ms = 6, label ="nomean")
plt.plot(mydat.posmean, c = "darkorange", ls = '--', marker = "s",
         ms = 6, label ="posmean") # ms = marker size
plt.legend(loc = 'upper right',bbox_to_anchor = (1,1))
plt.xticks(list(range(20)), rotation = 'vertical') # sets the ticks on
                                                   # x-axis and puts
                                                   # them vertically.
# Out:
# ([<matplotlib.axis.XTick at 0x118e4db80>,
#   <matplotlib.axis.XTick at 0x118e4db50>,
#   <matplotlib.axis.XTick at 0x118cfcd00>,
#   <matplotlib.axis.XTick at 0x118e9ab50>,
#   <matplotlib.axis.XTick at 0x118ea90a0>,
#   <matplotlib.axis.XTick at 0x118ea95b0>,
#   <matplotlib.axis.XTick at 0x118ea9ac0>,
#   <matplotlib.axis.XTick at 0x118ea9fd0>,
#   <matplotlib.axis.XTick at 0x118eaf520>,
#   <matplotlib.axis.XTick at 0x118eafa30>,
#   <matplotlib.axis.XTick at 0x118ea97f0>,
#   <matplotlib.axis.XTick at 0x118e9a2b0>,
#   <matplotlib.axis.XTick at 0x118eaf0a0>,
#   <matplotlib.axis.XTick at 0x118eb82e0>,
#   <matplotlib.axis.XTick at 0x118eb87f0>,
#   <matplotlib.axis.XTick at 0x118eb8d00>,
#   <matplotlib.axis.XTick at 0x118ebc250>,
#   <matplotlib.axis.XTick at 0x118ebc760>,
#   <matplotlib.axis.XTick at 0x118ebcc70>,
#   <matplotlib.axis.XTick at 0x118eb8850>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
